# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests
from datetime import datetime
import numpy as np
from scipy.stats import norm
from mystic.solvers import fmin

# %%
pd.options.mode.chained_assignment = None

# %%
url = "https://min-api.cryptocompare.com/data/histominute?fsym=BTC&tsym=KRW&limit=2000"

# %%
df1 = pd.DataFrame(requests.get(url).json()['Data'])
dindex = pd.DatetimeIndex([datetime.utcfromtimestamp(df1.time[i]+3600*9) for i in range(2001)])
df2 = pd.DataFrame(requests.get(url).json()['Data'],dindex)
df2 = df2.drop(columns=['volumefrom','time'])
df2 = df2.astype('int64')

# %%
df2['dP'] = df2['close'].diff()

# %%
df2['fdP'] = np.nan

# %%
df2['ldP'] = (df2['dP']-df2['dP'].mean())/df2['dP'].std()
df2['lP'] = (df2['close']-df2['close'].mean())/df2['close'].std()

# %%
dPstd = np.std(df2.dP)

# %%
df2['Buy'] = [(df2.volumeto[i])*norm.cdf(df2.dP[i]/dPstd,loc = 0,scale = 1) for i in range(2001)]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1738: RuntimeWarning: invalid value encountered in greater_equal
#   cond2 = (x >= self.b) & cond0

# %%
df2['Sell'] = df2['volumeto']-df2['Buy']

# %%
for i in range(1,len(df2)):
    df2['fdP'][i-1] = df2['dP'][i]

# %%
df2 = df2.drop([df2.index[2000],df2.index[0]])

# %%
df2['PIN'] = np.nan
df2['rDelta'] = np.nan

# %%
def Inloglike(params):
    LogLike = 0
    a, d, es, eb, mu = params
    
    for i in range(100):
        B = b[i]*np.log(1+mu/eb)
        S = s[i]*np.log(1+(mu)/(es))
    
        k1 = -mu-B
        k2 = -mu-S
        k3 = -B-S
        km = np.max([k1,k2,k3])
    
        LogLike += (
        np.log(a*d*np.e**(k1-km)+a*(1-d)*np.e**(k2-km)+(1-a)*np.e**(k3-km))
        +b[i]*np.log(eb+mu)+s[i]*np.log(es+mu)-(eb+es)+km
        )
    return -LogLike

# %%
for i in range(1000,len(df2),1):
    b = df2['Buy'][i-100:i]
    s = df2['Sell'][i-100:i]       
    res = fmin(Inloglike,[0.25,0.5,s.mean(),b.mean(),s.min()+b.min()],
        bounds = [(0,1),(0,1),(s.min(),s.max()),(b.min(),b.max()),(0,s.max()+b.max())],
            disp = False, xtol = 1e-3, ftol=1e-1
        )
        
    
    df2['PIN'][i] = res[0]*res[4]/(res[0]*res[4]+res[2]+res[3])
    df2['rDelta'][i] = 1-res[1]
    
    print(i)
# Out:
# 1000
# 1001
# 1002
# 1003
# 1004
# 1005
# 1006
# 1007
# 1008
# 1009
# 1010
# 1011
# 1012
# 1013
# 1014
# 1015
# 1016
# 1017
# 1018
# 1019
# 1020
# 1021
# 1022
# 1023
# 1024
# 1025
# 1026
# 1027
# 1028
# 1029
# 1030
# 1031
# 1032
# 1033
# 1034
# 1035
# 1036
# 1037
# 1038
# 1039
# 1040
# 1041
# 1042
# 1043
# 1044
# 1045
# 1046
# 1047
# 1048
# 1049
# 1050
# 1051
# 1052
# 1053
# 1054
# 1055
# 1056
# 1057
# 1058
# 1059
# 1060
# 1061
# 1062
# 1063
# 1064
# 1065
# 1066
# 1067
# 1068
# 1069
# 1070
# 1071
# 1072
# 1073
# 1074
# 1075
# 1076
# 1077
# 1078
# 1079
# 1080
# 1081
# 1082
# 1083
# 1084
# 1085
# 1086
# 1087
# 1088
# 1089
# 1090
# 1091
# 1092
# 1093
# 1094
# 1095
# 1096
# 1097
# 1098
# 1099
# 1100
# 1101
# 1102
# 1103
# 1104
# 1105
# 1106
# 1107
# 1108
# 1109
# 1110
# 1111
# 1112
# 1113
# 1114
# 1115
# 1116
# 1117
# 1118
# 1119
# 1120
# 1121
# 1122
# 1123
# 1124
# 1125
# 1126
# 1127
# 1128
# 1129
# 1130
# 1131
# 1132
# 1133
# 1134
# 1135
# 1136
# 1137
# 1138
# 1139
# 1140
# 1141
# ...

# %%
#p1 = df2['close'][1000:len(df2)].plot(color='r')
#p2 = p1.twinx()
(df2['rDelta'])[1000:len(df2)].plot()#nelder

# %%
p1 = df2['PIN'].diff()[1000:len(df2)].plot(color = 'r')
p2 = p1.twinx()
#np.abs(df2['lP'])[1000:len(df2)].plot()
#df2['rDelta'][[1500:len(df2)]].plot(color='g')

# %%
from arch import arch_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-f7e7e7ccf968> in <module>
# ----> 1 from arch import arch_model
#
# ModuleNotFoundError: No module named 'arch'

# %%
df2['gvar'] = np.nan
df2['gvarf'] = np.nan

# %%
for i in range(1000,len(df2),1):
    try:
        gam = arch_model(df2['ldP'][i-1000:i],p=2,o=1,q=2)
        gres = gam.fit(disp='off',show_warning=False)
        g = gres.forecast()
        df2['gvarf'][i] = g.residual_variance[-1:].values  
        df2['gvar'][i] = gres.conditional_volatility[-1:].values
        print(i)
    except Warning:
        continue
# Out:
# 1000
# 1001
# 1002
# 1003
# 1004
# 1005
# 1006
# 1007
# 1008
# 1009
# 1010
# 1011
# 1012
# 1013
# 1014
# 1015
# 1016
# 1017
# 1018
# 1019
# 1020
# 1021
# 1022
# 1023
# 1024
# 1025
# 1026
# 1027
# 1028
# 1029
# 1030
# 1031
# 1032
# 1033
# 1034
# 1035
# 1036
# 1037
# 1038
# 1039
# 1040
# 1041
# 1042
# 1043
# 1044
# 1045
# 1046
# 1047
# 1048
# 1049
# 1050
# 1051
# 1052
# 1053
# 1054
# 1055
# 1056
# 1057
# 1058
# 1059
# 1060
# 1061
# 1062
# 1063
# 1064
# 1065
# 1066
# 1067
# 1068
# 1069
# 1070
# 1071
# 1072
# 1073
# 1074
# 1075
# 1076
# 1077
# 1078
# 1079
# 1080
# 1081
# 1082
# 1083
# 1084
# 1085
# 1086
# 1087
# 1088
# 1089
# 1090
# 1091
# 1092
# 1093
# 1094
# 1095
# 1096
# 1097
# 1098
# 1099
# 1100
# 1101
# 1102
# 1103
# 1104
# 1105
# 1106
# 1107
# 1108
# 1109
# 1110
# 1111
# 1112
# 1113
# 1114
# 1115
# 1116
# 1117
# 1118
# 1119
# 1120
# 1121
# 1122
# 1123
# 1124
# 1125
# 1126
# 1127
# 1128
# 1129
# 1130
# 1131
# 1132
# 1133
# 1134
# 1135
# 1136
# 1137
# 1138
# 1139
# 1140
# 1141
# ...

# %%
p1 = np.abs(df2['ldP'])[1000:2000].plot(color='r')
p2 = p1.twinx()
df2['gvar'][1000:2000].plot()

# %%
p1 = np.abs(df2['gvar'])[1000:2000].plot(color='r')
p2 = p1.twinx()
df2['gvarf'][1000:2000].plot()

# %%
p = 0.5
np.sum((df2['rDelta'][1000:2000]>=p)&(df2['fdP'][1000:2000]>=0))/np.sum(df2['rDelta'][1000:2000]>=p)

# %%
p = 0.5
np.sum((df2['fdP'][1000:2000]<=0) & (df2['rDelta'][1000:2000]<=p))/np.sum(df2['rDelta'][1000:2000]<=p)

# %%
vp = np.percentile(df2['gvar'][1000:2000].values,60)
adp = np.percentile(np.abs(df2['dP'][1000:2000]).values,50)
(
    np.sum((np.abs(df2['fdP'][1000:2000])>adp)&(df2['gvar'][1000:2000]>vp))/
    np.sum(df2['gvar'][1000:2000]>vp)
)

# %%
vp = np.percentile(df2['gvar'][1000:2000].values,75)
(
    np.sum(((df2['dP'][1000:1999].values*df2['fdP'][1000:1999].values)<=0)&(df2['gvar'][1000:1999]>vp))/
    np.sum(df2['gvar'][1000:1999]>vp)
)

# %%
vp = np.percentile(df2['gvar'][1000:2000].values,25)
(
    np.sum(((df2['dP'][1000:1999].values*df2['fdP'][1000:1999].values)<=0)&(df2['gvar'][1000:1999]<vp))/
    np.sum(df2['gvar'][1000:2000]<vp)
)

# %%
vp = np.percentile(df2['gvar'][1000:2000].values,25)
vp2 = np.percentile(df2['gvar'][1000:2000].values,0)
p = 0.50
print(
    np.sum(((
        df2['gvar'][1000:1999].values<vp)
        & (df2['gvar'][1000:1999].values>vp2))
        & (df2['rDelta'][1000:1999].values>p)
        & (df2['dP'][1000:1999].values<=0)
        & (df2['fdP'][1000:1999].values>=0))
    /np.sum((
        (df2['gvar'][1000:1999].values<vp)
        & (df2['gvar'][1000:1999].values>vp2))
        & (df2['rDelta'][1000:1999].values>p)
        & (df2['dP'][1000:1999].values<=0)
    )
)
# 변동성이0-25% p가 크고 직전에 감소했을때 올라갈확률
print(np.sum((
        (df2['gvar'][1000:1999].values<vp)
        & (df2['gvar'][1000:1999].values>vp2))
        & (df2['rDelta'][1000:1999].values>p)
        & (df2['dP'][1000:1999].values<=0)
    ))

# %%
vp = np.percentile(df2['gvar'][1000:2000].values,50)
vp2 = np.percentile(df2['gvar'][1000:2000].values,25)
p = 0.50
print(
    np.sum(((
        df2['gvar'][1000:1999].values<vp)
        & (df2['gvar'][1000:1999].values>vp2))
        & (df2['rDelta'][1000:1999].values>p)
        & (df2['dP'][1000:1999].values<=0)
        & (df2['fdP'][1000:1999].values>=0))
    /np.sum((
        (df2['gvar'][1000:1999].values<vp)
        & (df2['gvar'][1000:1999].values>vp2))
        & (df2['rDelta'][1000:1999].values>p)
        & (df2['dP'][1000:1999].values<=0)
    )
)
# 변동성이25-50% p가 크고 직전에 감소했을때 올라갈확률
print(np.sum((
        (df2['gvar'][1000:1999].values<vp)
        & (df2['gvar'][1000:1999].values>vp2))
        & (df2['rDelta'][1000:1999].values>p)
        & (df2['dP'][1000:1999].values<=0)
    ))

# %%
vp = np.percentile(df2['gvar'][1000:2000].values,75)
vp2 = np.percentile(df2['gvar'][1000:2000].values,50)
p = 0.50
print(
    np.sum(((
        df2['gvar'][1000:1999].values<vp)
        & (df2['gvar'][1000:1999].values>vp2))
        & (df2['rDelta'][1000:1999].values>p)
        & (df2['dP'][1000:1999].values<=0)
        & (df2['fdP'][1000:1999].values>=0))
    /np.sum((
        (df2['gvar'][1000:1999].values<vp)
        & (df2['gvar'][1000:1999].values>vp2))
        & (df2['rDelta'][1000:1999].values>p)
        & (df2['dP'][1000:1999].values<=0)
    )
)
# 변동성이50-75% p가 크고 직전에 감소했을때 올라갈확률
print(np.sum((
        (df2['gvar'][1000:1999].values<vp)
        & (df2['gvar'][1000:1999].values>vp2))
        & (df2['rDelta'][1000:1999].values>p)
        & (df2['dP'][1000:1999].values<=0)
    ))

# %%
vp = np.percentile(df2['gvar'][1000:2000].values,100)
vp2 = np.percentile(df2['gvar'][1000:2000].values,75)
p = 0.50
print(
    np.sum(((
        df2['gvar'][1000:1999].values<vp)
        & (df2['gvar'][1000:1999].values>vp2))
        & (df2['rDelta'][1000:1999].values>p)
        & (df2['dP'][1000:1999].values<=0)
        & (df2['fdP'][1000:1999].values>=0))
    /np.sum((
        (df2['gvar'][1000:1999].values<vp)
        & (df2['gvar'][1000:1999].values>vp2))
        & (df2['rDelta'][1000:1999].values>p)
        & (df2['dP'][1000:1999].values<=0)
    )
)
# 변동성이75-100% p가 크고 직전에 감소했을때 올라갈확률
print(np.sum((
        (df2['gvar'][1000:1999].values<vp)
        & (df2['gvar'][1000:1999].values>vp2))
        & (df2['rDelta'][1000:1999].values>p)
        & (df2['dP'][1000:1999].values<=0)
    ))

# %%
vp = np.percentile(df2['gvar'][1000:2000].values,25)
vp2 = np.percentile(df2['gvar'][1000:2000].values,0)
p = 0.5
print(
    np.sum(((
        df2['gvar'][1000:1999].values<vp)
        & (df2['gvar'][1000:1999].values>vp2))
        & (df2['rDelta'][1000:1999].values<p)
        & (df2['dP'][1000:1999].values>=0)
        & (df2['fdP'][1000:1999].values<=0))
    /np.sum((
        (df2['gvar'][1000:1999].values<vp)
        & (df2['gvar'][1000:1999].values>vp2))
        & (df2['rDelta'][1000:1999].values<p)
        & (df2['dP'][1000:1999].values>=0)
    )
)
# 변동성이0-25% p가 작고 직전에 증가했을때 감소할확률
print(np.sum((
        (df2['gvar'][1000:1999].values<vp)
        & (df2['gvar'][1000:1999].values>vp2))
        & (df2['rDelta'][1000:1999].values<p)
        & (df2['dP'][1000:1999].values>=0)
    ))

# %%
vp = np.percentile(df2['gvar'][1000:2000].values,50)
vp2 = np.percentile(df2['gvar'][1000:2000].values,25)
p = 0.5
print(
    np.sum(((
        df2['gvar'][1000:1999].values<vp)
        & (df2['gvar'][1000:1999].values>vp2))
        & (df2['rDelta'][1000:1999].values<p)
        & (df2['dP'][1000:1999].values>=0)
        & (df2['fdP'][1000:1999].values<=0))
    /np.sum((
        (df2['gvar'][1000:1999].values<vp)
        & (df2['gvar'][1000:1999].values>vp2))
        & (df2['rDelta'][1000:1999].values<p)
        & (df2['dP'][1000:1999].values>=0)
    )
)
# 변동성이25-50% p가 작고 직전에 증가했을때 감소할확률
print(np.sum((
        (df2['gvar'][1000:1999].values<vp)
        & (df2['gvar'][1000:1999].values>vp2))
        & (df2['rDelta'][1000:1999].values<p)
        & (df2['dP'][1000:1999].values>=0)
    ))

# %%
vp = np.percentile(df2['gvar'][1000:2000].values,75)
vp2 = np.percentile(df2['gvar'][1000:2000].values,50)
p = 0.5
print(
    np.sum(((
        df2['gvar'][1000:1999].values<vp)
        & (df2['gvar'][1000:1999].values>vp2))
        & (df2['rDelta'][1000:1999].values<p)
        & (df2['dP'][1000:1999].values>=0)
        & (df2['fdP'][1000:1999].values<=0))
    /np.sum((
        (df2['gvar'][1000:1999].values<vp)
        & (df2['gvar'][1000:1999].values>vp2))
        & (df2['rDelta'][1000:1999].values<p)
        & (df2['dP'][1000:1999].values>=0)
    )
)
# 변동성이50-75% p가 작고 직전에 증가했을때 감소할확률
print(np.sum((
        (df2['gvar'][1000:1999].values<vp)
        & (df2['gvar'][1000:1999].values>vp2))
        & (df2['rDelta'][1000:1999].values<p)
        & (df2['dP'][1000:1999].values>=0)
    ))

# %%
vp = np.percentile(df2['gvar'][1000:2000].values,75)
p = 0.5
print(
    np.sum((
        df2['gvar'][1000:1999].values>vp) & (df2['rDelta'][1000:1999].values<p)
        & (df2['dP'][1000:1999].values>=0)
        & (df2['fdP'][1000:1999].values<=0))
    /np.sum(
        (df2['gvar'][1000:1999].values>vp) & (df2['rDelta'][1000:1999].values<p) 
        & (df2['dP'][1000:1999].values>=0)
    )
)
# 변동성이75-100% p가 작고 직전에 증가했을때 감소할 확률
print(np.sum(
        (df2['gvar'][1000:1999].values<vp) & (df2['rDelta'][1000:1999].values<p) 
        & (df2['dP'][1000:1999].values>=0)
    ))

# %% [markdown]
# ### 부가

# %%
vp = np.percentile(df2['gvar'][1000:2000].values,90)
p = 0.6
p2 = 0.4
print(
    np.sum((
        df2['gvar'][1000:1999].values>vp) 
        & (df2['rDelta'][1000:1999].values<p)
        & (df2['rDelta'][1000:1999].values>1-p)
        & (df2['dP'][1000:1999].values<=0)
        & (df2['fdP'][1000:1999].values>=0))
    /np.sum(
        (df2['gvar'][1000:1999].values>vp) 
        & (df2['rDelta'][1000:1999].values<p)
        & (df2['rDelta'][1000:1999].values>1-p)
        & (df2['dP'][1000:1999].values<=0)
    )
)
# 변동성이 크고 p가 중앙부근 직전에 감소했을때 증가할 확률
print(np.sum(
        (df2['gvar'][1000:1999].values>vp) 
        & (df2['rDelta'][1000:1999].values<p)
        & (df2['rDelta'][1000:1999].values>1-p)
        & (df2['dP'][1000:1999].values<=0)
    ))

# %%
vp = np.percentile(df2['gvar'][1000:2000].values,90)
p = 0.52
p2 = 0.48
print(
    np.sum((
        df2['gvar'][1000:1999].values>vp) 
        & (df2['rDelta'][1000:1999].values<p)
        & (df2['rDelta'][1000:1999].values>p2)
        & (df2['dP'][1000:1999].values>=0)
        & (df2['fdP'][1000:1999].values<=0))
    /np.sum(
        (df2['gvar'][1000:1999].values>vp) 
        & (df2['rDelta'][1000:1999].values<p)
        & (df2['rDelta'][1000:1999].values>p2)
        & (df2['dP'][1000:1999].values>=0)
    )
)
# 변동성이 크고 p가 중앙부근 직전에 증가했을때 감소할 확률
print(np.sum(
        (df2['gvar'][1000:1999].values>vp) 
        & (df2['rDelta'][1000:1999].values<p)
        & (df2['rDelta'][1000:1999].values>p2)
        & (df2['dP'][1000:1999].values>=0)
    ))
